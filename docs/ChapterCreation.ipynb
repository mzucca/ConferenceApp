# %%
from openai import AzureOpenAI
 
import os
import json
import pandas as pd
import pypandoc

# %%
#!pip uninstall pypandoc_binary

# %%
client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_KEY"),  
    api_version="2023-12-01-preview",
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
)

# %%
def get_completion(prompt, model="gpt-35-turbo"):
    messages = [{"role": "user", "content": prompt}]
    try:
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            #response_format={ "type": "json_object" },
            model=model,
            temperature=0,
        )
        #print(response)
        return response.choices[0].message.content
    except Exception as e:
        print(e)

# %%
prompt_summarization_1 = """
You are an expert software developer expert in software documentation.
Your job is to tranform a transcription into a detailed description of a module:
'''{customer_request}'''.
You have to create a detailed and professional description of the described module. Please put in evidence significant piece of code. Write it in markdown starting from level 2.
"""

# %%
customer_request = """
Creating Server Routes - Friends Invitations
Let's create a new roads at our server and what we just need to do.

Let's go to our server trace file in the discord back in the folder and here before.

Here we have the logic to register the roots and as we see, we have two of roots for their logging

and registration and also use the roots for friend invitation.

And here what will pass will just pass their friend invitation roots.

Of course, we need to create that file.

And what we can do, it already lets out just require that file, which will create and that will be

friend invitation roots and will just require the roots.

And it will go for friend invitation.

But we don't have that file.

Let's create this right now.

And it's coming to the Roots folder, where we keep the information about the roots, which we have.

And we just need to create a new file friend invitation roots to trace.

And let's make that in the same pattern as we have been doing with that of her roots.

And we know that we need to express and the router joy and the off controller will be not necessary

so we can copy everything from here.

Also, the offer will be necessary because we'll be checking if the user like this has a valid travel

token.

And so what we will not need the off controllers will be not needed here, but we will use to express

router joy validator and of to check for the gravity token.

And now we need to define our schema and for what name we can go.

We can use.

Post invitation schema.

So what we have here that we have different invitation, that register schema will be using this like

this, but we can remove that and just write the new schema so will be post in the station schema or

we can even post front invitation schema like this.

And of course, that will be here, we just need to find the rules, which we will be checking our validation.

And I would like to go that male of this user, which would like to invite should be the joy string

e-mail.

And now Joe will be checking if that.

Made, which we have passed from the React application is invalid mail address, but I would like to

change this name, which will also change the front end of our application in our dialogue that we would

like for trustful to go for direct target mail address.

That's we'll just have more information of that.

Value, which we are passing, that that's the target to which would like to invite, but we just need

to remember to change that later on at our React application when we'll be sending the request because

we are passing the mail, not the target to others.

And now, as we have created that, we can create that post request.

And that should be available under the invite.

And here we'll pass that off, because we would like to check the for the if the DVD token is valid.

So already we have prepared that before in our image, the where to check that and also will pass the

validator dot body as the next middleware, because here after the DVD token will be fine later on,

we would like to check if the payload of the data which is coming in this request request is coming

and at the end we would like to execute our control order, which we have not created, and that will

be their friend invitation.

Controllers, which will create, of course, because we don't have that right now and will go for the

controllers and just for post invite like this.

And of course, as we have that, what we are missing, we need to close it, we have to brace and now

what we are missing.

Post friend invitations came out like this, it's fine.

This one should go to the one line.

And now what we are missing, we should remove probably one brace at the end.

And now it's fine, ladies.

So what we are doing, our URL of the invitation will be here like an API friend invitation.

And that would be just the invite, and that will be the post's request.

Well, first we'll check the gravity token later on will validate if then email address, which we have

passed is the invalid email address and later, if yes, we'll just pass this request to our conflict

controller.

And that's everything.

And as we have done that, let's create our friend invitation controllers, and now we have the file

of the controllers and we'll create the.

Folder inside, because here we have two of controllers, and just here in the controls for that will

create a new one of the name of friend invitation.

Like this?

And now in this folder, we'll create a new file of the name of friend.

Invitation controllers, dot jets and will create that first controller, which will need of the name

of post unified dog chiefs.

Now in different invitation controllers would be just the file, which will be collecting our controllers

from this folder.

So the first one will be post invite where it will just require that post invite controller, which

will create and will just export controllers and will call for post invite ladies.

Now we can start creating that controller will just send the simple response to the user and literally

just write the logic of it.

So we'll have that post invite.

And that will be a think because we would like to save that information about that front in the fight

in our database.

And as we have that, we've got the target e-mail address from request body and now us, we'll have

that just sent right now the simple response rest response object, which we are getting from the express

application and will go.

Return response dot.

We'll just send the information.

Hi.

Although drugs controller is working.

And now let's check if we will make an API request from our reactor application will be able to get

that response in the reactor application in the network tap.

But we just need to change it because here we are waiting for in the front invitation rules for the.

In the body, we should have the target male others, not the male, just.

So we can just change it up in the upfront dialogue, in our React application, in the dashboard folder,

friends side bar and friendly dialogue and here just sent front invitation.

The object data, which we are passing, will just change the value from the email to target many others.

And now let's save this.

I think that would be good to restart our server, but we have even an error.

Let's try to start this once again.

It's not working because we have an error somewhere in the front invitation her roots.

So let's go to our friend invitational roots, which we have created.

And here what we are getting the information that friend invitation.

Controllers.

Are not defined because, of course, we need to require this, so go like this as a second friend,

invitation controls will require that.

File, which we have are collecting all of the controllers, VAT with different invitations, sole goal

controllers, front invitation.

And here we have that file front invitation controllers that save this.

Let's start this once again.

Now here we are getting an error.

Who wrote that post?

Well, we have a simple error and probably is in the.

We are getting information that we have created at the server here, that front invitation erodes.

But what is going on exactly that in the front invitation, the roots, if we are configuring the new

routes to related with the router, we just at the end each export this router because we are not getting

anything from this file.

So the reason is that why it's not working.

So that was and one error, which we have right now corrected, and now we have one more.

Deal.

We are getting the error, but the reason for that is that in our post invite to trace file, we have

not exported that function, which we have created, so we just need to add them module exports.

Post invite, just remember to add to all of the necessary exports to make our set of our working dirigeant

estate that we have forgot to export, and we were not able to make that working.

But after we have added them, we are seeing that our server started successfully.

So refresh right now, our React application.

Now what we can do it, let's go and upfront pass just the -- email address.

That's number two at Gmail dot com.

And now we can go and just send it.

And what will get the information right here?

This process is not defined right now.

That's the error related.

We've.

React is there on back it up to hot reload is the problem with the hot reload, so it's just not related

with our application that should be fixed soon.

But now we can go to the network top.

And we are seeing that we got the response from the server that the controller is working and we have

passed the data to the server payload, which is target mail address.

And we are seeing this mail, which we have sent and we are able to reach our controller.

And right now, we'll be able to write this logic.

Here we are seeing the information that the closed dialog handler is not a function, because if we

will get the successful response from the server like 200, we should close this dialog.

And the reason for that why it's not working if you go to the art front dialog.

If we are sending the free French invitation after the first parameter, which is data also, we should

pass the handler to close dialog, handle close dialog because in this action, which is sent French

invitation that you go to different actions as you are seeing, we are accepting the closed dialogue

conundrum, which we have not passed.

And now if the response will be successful, there will be no error.

So we'll have like a 200 response.

We should execute that close dialogue handler so we can check this once again.

That's closer at front, right?

And dummy address, which is said test at Test.

Com and will send and the response from the server will be final.

Like a 200 will just get information.

Invitation has been sent.

But we have a lot of things to do in that controller to save that invitation in our database and to check if the invitation has been already sent.
Our.
That invitation does not exist and depends what or even the email address cannot exist of this friend.
So we would like to retain the information that this friend does not exist, that we should check this email once again.
So we'll do it.
All of that feels right now.
"""

# %%
response = get_completion(prompt_summarization_1.format(customer_request=customer_request),model="gpt-35-turbo")#gpt-35-turbo gpt-4
print(response)
# Out:
# ## Module Description: Creating Server Routes - Friends Invitations
#
# The module is responsible for creating server routes for handling friend invitations. It involves the creation of routes, controllers, and validation schemas to facilitate the process of sending and handling friend invitations.
#
# ### Server Trace File
# The server trace file is used to register the routes for logging, registration, and friend invitations. It involves creating a new file for friend invitation routes and defining the necessary logic for handling friend invitations.
#
# ### Friend Invitation Routes
# The module creates a new file for friend invitation routes in the "Roots" folder. It defines the routes and uses Express, Router Joy, and validation middleware to handle the friend invitation process. The module also defines a validation schema for the post invitation, ensuring that the email address provided is valid.
#
# Significant piece of code:
# ```javascript
# ...

# %%
with open('output.md', 'w') as f:
    f.write(response)

# %%
pypandoc.convert_file('output.md', 'docx', outputfile="output.docx")
# Out:
# ''
